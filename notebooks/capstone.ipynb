# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
owid_df = pd.read_csv('../data/energy-data/owid-energy-data.csv')

# %%
gov_response = pd.read_csv('../data/covid-policy-dataset/data/timeseries_indices/OxCGRT_timeseries_GovernmentResponseIndex_v1.csv')

# %%
primary_cons = pd.read_excel('../data/Statistical Review of World Energy Data.xlsx'
                             ,sheet_name='Primary energy cons - EJ'
                             ,skiprows=range(0,2)
                            ,skipfooter=11)

# %%
primary_cons.rename(columns={'Exajoules':'Country'}, inplace=True)

# %%
gov_response_countries = gov_response[gov_response['Jurisdiction']=='NAT_TOTAL']

# %%
print(primary_cons['Country'].to_string())
# Out:
# 0                           NaN
# 1                        Canada
# 2                        Mexico
# 3                            US
# 4           Total North America
# 5                           NaN
# 6                     Argentina
# 7                        Brazil
# 8                         Chile
# 9                      Colombia
# 10                      Ecuador
# 11                         Peru
# 12            Trinidad & Tobago
# 13                    Venezuela
# 14              Central America
# 15              Other Caribbean
# 16          Other South America
# 17     Total S. & Cent. America
# 18                          NaN
# 19                      Austria
# 20                      Belgium
# 21                     Bulgaria
# 22                      Croatia
# 23                       Cyprus
# 24               Czech Republic
# 25                      Denmark
# 26                      Estonia
# 27                      Finland
# 28                       France
# 29                      Germany
# 30                       Greece
# 31                      Hungary
# 32                      Iceland
# 33                      Ireland
# 34                        Italy
# 35                       Latvia
# 36                    Lithuania
# 37                   Luxembourg
# 38                  Netherlands
# 39              North Macedonia
# 40                       Norway
# 41                       Poland
# 42                     Portugal
# 43                      Romania
# 44                     Slovakia
# 45                     Slovenia
# 46                        Spain
# 47                       Sweden
# 48                  Switzerland
# 49                       Turkey
# 50                      Ukraine
# 51               United Kingdom
# 52                 Other Europe
# 53                 Total Europe
# 54                          NaN
# 55                   Azerbaijan
# 56                      Belarus
# 57                   Kazakhstan
# 58           Russian Federation
# 59                 Turkmenistan
# 60                         USSR
# 61                   Uzbekistan
# 62                    Other CIS
# 63                    Total CIS
# 64                          NaN
# 65                         Iran
# 66                         Iraq
# 67                       Israel
# 68                       Kuwait
# 69                         Oman
# 70                        Qatar
# 71                 Saudi Arabia
# 72         United Arab Emirates
# 73            Other Middle East
# 74            Total Middle East
# 75                          NaN
# 76                      Algeria
# 77                        Egypt
# 78                      Morocco
# 79                 South Africa
# 80               Eastern Africa
# 81                Middle Africa
# 82               Western Africa
# 83        Other Northern Africa
# 84        Other Southern Africa
# 85                 Total Africa
# 86                          NaN
# 87                    Australia
# 88                   Bangladesh
# 89                        China
# 90          China Hong Kong SAR
# 91                        India
# 92                    Indonesia
# 93                        Japan
# 94                     Malaysia
# 95                  New Zealand
# 96                     Pakistan
# 97                  Philippines
# 98                    Singapore
# 99                  South Korea
# 100                   Sri Lanka
# 101                      Taiwan
# 102                    Thailand
# 103                     Vietnam
# 104          Other Asia Pacific
# 105          Total Asia Pacific
# 106                         NaN

# %%
gov_response_rotate = gov_response_countries[gov_response_countries['CountryName'].isin(owid_df['country'])].drop(columns=['CountryCode'
                                                                                                          ,'RegionCode'
                                                                                                          ,'RegionName'
                                                                                                          ,'CityCode'
                                                                                                          ,'CityName'
                                                                                                          ,'Jurisdiction']).transpose().reset_index()

# %%
primary_cons_rotate = primary_cons[primary_cons['Country'].isin(gov_response_countries['CountryName'])][['Country',2019,2020,2021,2022,2023]].reset_index(drop=True).transpose()

# %%
primary_cons_rotate.columns = primary_cons_rotate.iloc[0]

# %%
primary_cons_rotate = primary_cons_rotate.reset_index().drop(index=0).reset_index(drop=True).rename(columns={'index':'Year'}).apply(pd.to_numeric)

# %%
gov_response_rotate.columns = gov_response_rotate.iloc[0]

# %%
gov_response_rotate = gov_response_rotate.drop(index=0).rename(columns={'CountryName':'Date'}).reset_index(drop=True)

# %%
gov_num = gov_response_rotate.iloc[:,1:73].apply(pd.to_numeric)

# %%
gov_date = gov_response_rotate.iloc[:,0].apply(pd.to_datetime)

# %%
gov_response_rotate.columns[1:]
# Out:
# Index(['Aruba', 'Afghanistan', 'Angola', 'Albania', 'United Arab Emirates',
#        'Argentina', 'Australia', 'Austria', 'Azerbaijan', 'Burundi',
#        ...
#        'United States', 'Uzbekistan', 'Venezuela',
#        'United States Virgin Islands', 'Vietnam', 'Vanuatu', 'Yemen',
#        'South Africa', 'Zambia', 'Zimbabwe'],
#       dtype='object', name=0, length=176)

# %%
gov_num.insert(0,'Date',gov_date)

# %%
gov_num['Year'] = gov_num['Date'].dt.year

# %%
gov_mean = gov_num.groupby('Year').mean().reset_index().drop(columns='Date')

# %%
primary_cons_rotate = primary_cons_rotate.reset_index(drop=True)

# %%
gov_melt = gov_mean.melt(id_vars=['Year'],value_vars=gov_mean.columns[1:]).rename(columns={0:'Country'})

# %%
primary_cons_rotate
# Out:
# Country  Year     Canada    Mexico  Argentina     Brazil     Chile  Colombia  \
# 0        2019  14.644261  8.069090   3.338490  12.718623  1.706323  2.027493
# 1        2020  13.758059  7.350903   3.131383  12.219726  1.592920  1.845309
# 2        2021  13.921114  7.833220   3.450466  12.854411  1.716685  2.069083
# 3        2022  14.299105  8.183102   3.705772  13.435922  1.812619  2.196243
# 4        2023  13.949592  8.452957   3.671069  13.873373  1.814643  2.255347
#
# Country   Ecuador      Peru  Venezuela  ...  Malaysia  New Zealand  Pakistan  \
# 0        0.760799  1.175707   2.365085  ...  4.466813     0.949265  3.537059
# 1        0.658305  1.036308   1.900297  ...  4.307145     0.861325  3.517981
# 2        0.765349  1.178669   2.174710  ...  4.487938     0.847978  3.901649
# 3        0.801823  1.216668   2.341003  ...  4.792605     0.835960  3.595340
# 4        0.843516  1.237765   2.531421  ...  4.807117     0.860885  3.372125
#
# Country  Philippines  Singapore  South Korea  Sri Lanka    Taiwan  Thailand  \
# 0           2.038037   3.346846    12.465634   0.406927  4.790488  5.327082
# 1           1.849511   3.277865    12.049074   0.381602  4.650168  4.952731
# 2           1.963837   3.278570    12.623430   0.394695  4.942589  4.992516
# 3           2.055580   3.174647    12.752438   0.351276  4.747891  4.996416
# 4           2.193169   3.470479    12.434021   0.357512  4.528818  5.006924
#
# Country   Vietnam
# 0        4.329488
# 1        4.335817
# 2        4.350794
# 3        4.478643
# 4        4.891435
#
# [5 rows x 74 columns]

# %%
gov_mean.to_csv('mean_restrictions.csv', index=False)

# %%
primary_cons_rotate.to_csv('primary_consumption.csv',index=False)

# %%
gov_melt.to_csv('gov_melt.csv',index=False)

# %%
gov_melt
# Out:
#      Year      Country      value
# 0    2020        Aruba  42.321585
# 1    2021        Aruba  42.214740
# 2    2022        Aruba  31.981726
# 3    2023        Aruba        NaN
# 4    2020  Afghanistan  33.816694
# ..    ...          ...        ...
# 283  2023        Haiti        NaN
# 284  2020      Hungary  44.600109
# 285  2021      Hungary  53.617068
# 286  2022      Hungary  28.892521
# 287  2023      Hungary        NaN
#
# [288 rows x 3 columns]

# %%
owid_trim = owid_df[['country','year','coal_cons_per_capita','hydro_energy_per_capita','oil_energy_per_capita','nuclear_energy_per_capita','gas_energy_per_capita']]

# %%
owid_trim = owid_trim[(owid_trim['country'].isin(gov_melt['Country']))&(owid_trim['year'].between(2019,2023))].rename(columns={'country':'Country','year':'Year'})

# %%
gov_owid_merge = owid_trim.merge(gov_melt,how='outer',on=('Country','Year'))

# %%
#gov_owid_merge.to_csv('gov_owid_merge.csv',index=False)

# %%
gov_response[gov_response['CountryCode']=='USA']
# Out:
#     CountryCode    CountryName RegionCode      RegionName CityCode CityName  \
# 334         USA  United States      US_AK          Alaska      NaN      NaN
# 335         USA  United States      US_AL         Alabama      NaN      NaN
# 336         USA  United States      US_AR        Arkansas      NaN      NaN
# 337         USA  United States      US_AZ         Arizona      NaN      NaN
# 338         USA  United States      US_CA      California      NaN      NaN
# 339         USA  United States      US_CO        Colorado      NaN      NaN
# 340         USA  United States      US_CT     Connecticut      NaN      NaN
# 341         USA  United States      US_DC   Washington DC      NaN      NaN
# 342         USA  United States      US_DE        Delaware      NaN      NaN
# 343         USA  United States      US_FL         Florida      NaN      NaN
# 344         USA  United States      US_GA         Georgia      NaN      NaN
# 345         USA  United States      US_HI          Hawaii      NaN      NaN
# 346         USA  United States      US_IA            Iowa      NaN      NaN
# 347         USA  United States      US_ID           Idaho      NaN      NaN
# 348         USA  United States      US_IL        Illinois      NaN      NaN
# 349         USA  United States      US_IN         Indiana      NaN      NaN
# 350         USA  United States      US_KS          Kansas      NaN      NaN
# 351         USA  United States      US_KY        Kentucky      NaN      NaN
# 352         USA  United States      US_LA       Louisiana      NaN      NaN
# 353         USA  United States      US_MA   Massachusetts      NaN      NaN
# 354         USA  United States      US_MD        Maryland      NaN      NaN
# 355         USA  United States      US_ME           Maine      NaN      NaN
# 356         USA  United States      US_MI        Michigan      NaN      NaN
# 357         USA  United States      US_MN       Minnesota      NaN      NaN
# 358         USA  United States      US_MO        Missouri      NaN      NaN
# 359         USA  United States      US_MS     Mississippi      NaN      NaN
# 360         USA  United States      US_MT         Montana      NaN      NaN
# 361         USA  United States      US_NC  North Carolina      NaN      NaN
# 362         USA  United States      US_ND    North Dakota      NaN      NaN
# 363         USA  United States      US_NE        Nebraska      NaN      NaN
# 364         USA  United States      US_NH   New Hampshire      NaN      NaN
# 365         USA  United States      US_NJ      New Jersey      NaN      NaN
# 366         USA  United States      US_NM      New Mexico      NaN      NaN
# 367         USA  United States      US_NV          Nevada      NaN      NaN
# 368         USA  United States      US_NY        New York      NaN      NaN
# 369         USA  United States      US_OH            Ohio      NaN      NaN
# 370         USA  United States      US_OK        Oklahoma      NaN      NaN
# 371         USA  United States      US_OR          Oregon      NaN      NaN
# 372         USA  United States      US_PA    Pennsylvania      NaN      NaN
# 373         USA  United States      US_RI    Rhode Island      NaN      NaN
# 374         USA  United States      US_SC  South Carolina      NaN      NaN
# 375         USA  United States      US_SD    South Dakota      NaN      NaN
# 376         USA  United States      US_TN       Tennessee      NaN      NaN
# 377         USA  United States      US_TX           Texas      NaN      NaN
# 378         USA  United States      US_UT            Utah      NaN      NaN
# 379         USA  United States      US_VA        Virginia      NaN      NaN
# 380         USA  United States      US_VT         Vermont      NaN      NaN
# 381         USA  United States      US_WA      Washington      NaN      NaN
# 382         USA  United States      US_WI       Wisconsin      NaN      NaN
# 383         USA  United States      US_WV   West Virginia      NaN      NaN
# 384         USA  United States      US_WY         Wyoming      NaN      NaN
# 385         USA  United States        NaN             NaN      NaN      NaN
#
#     Jurisdiction  01Jan2020  02Jan2020  03Jan2020  ...  19Feb2023  20Feb2023  \
# 334  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 335  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 336  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 337  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 338  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 339  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 340  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 341  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 342  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 343  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 344  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 345  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 346  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 347  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 348  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 349  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 350  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 351  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 352  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 353  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 354  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 355  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 356  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 357  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 358  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 359  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 360  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 361  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 362  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 363  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 364  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 365  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 366  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 367  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 368  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 369  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 370  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 371  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 372  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 373  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 374  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 375  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 376  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 377  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 378  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 379  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 380  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 381  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 382  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 383  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 384  STATE_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
# 385    NAT_TOTAL        0.0        0.0        0.0  ...        NaN        NaN
#
#      21Feb2023  22Feb2023  23Feb2023  24Feb2023  25Feb2023  26Feb2023  \
# 334        NaN        NaN        NaN        NaN        NaN        NaN
# 335        NaN        NaN        NaN        NaN        NaN        NaN
# 336        NaN        NaN        NaN        NaN        NaN        NaN
# 337        NaN        NaN        NaN        NaN        NaN        NaN
# 338        NaN        NaN        NaN        NaN        NaN        NaN
# 339        NaN        NaN        NaN        NaN        NaN        NaN
# 340        NaN        NaN        NaN        NaN        NaN        NaN
# 341        NaN        NaN        NaN        NaN        NaN        NaN
# 342        NaN        NaN        NaN        NaN        NaN        NaN
# 343        NaN        NaN        NaN        NaN        NaN        NaN
# 344        NaN        NaN        NaN        NaN        NaN        NaN
# 345        NaN        NaN        NaN        NaN        NaN        NaN
# 346        NaN        NaN        NaN        NaN        NaN        NaN
# 347        NaN        NaN        NaN        NaN        NaN        NaN
# 348        NaN        NaN        NaN        NaN        NaN        NaN
# 349        NaN        NaN        NaN        NaN        NaN        NaN
# 350        NaN        NaN        NaN        NaN        NaN        NaN
# 351        NaN        NaN        NaN        NaN        NaN        NaN
# 352        NaN        NaN        NaN        NaN        NaN        NaN
# 353        NaN        NaN        NaN        NaN        NaN        NaN
# 354        NaN        NaN        NaN        NaN        NaN        NaN
# 355        NaN        NaN        NaN        NaN        NaN        NaN
# 356        NaN        NaN        NaN        NaN        NaN        NaN
# 357        NaN        NaN        NaN        NaN        NaN        NaN
# 358        NaN        NaN        NaN        NaN        NaN        NaN
# 359        NaN        NaN        NaN        NaN        NaN        NaN
# 360        NaN        NaN        NaN        NaN        NaN        NaN
# 361        NaN        NaN        NaN        NaN        NaN        NaN
# 362        NaN        NaN        NaN        NaN        NaN        NaN
# 363        NaN        NaN        NaN        NaN        NaN        NaN
# 364        NaN        NaN        NaN        NaN        NaN        NaN
# 365        NaN        NaN        NaN        NaN        NaN        NaN
# 366        NaN        NaN        NaN        NaN        NaN        NaN
# 367        NaN        NaN        NaN        NaN        NaN        NaN
# 368        NaN        NaN        NaN        NaN        NaN        NaN
# 369        NaN        NaN        NaN        NaN        NaN        NaN
# 370        NaN        NaN        NaN        NaN        NaN        NaN
# 371        NaN        NaN        NaN        NaN        NaN        NaN
# 372        NaN        NaN        NaN        NaN        NaN        NaN
# 373        NaN        NaN        NaN        NaN        NaN        NaN
# 374        NaN        NaN        NaN        NaN        NaN        NaN
# 375        NaN        NaN        NaN        NaN        NaN        NaN
# 376        NaN        NaN        NaN        NaN        NaN        NaN
# 377        NaN        NaN        NaN        NaN        NaN        NaN
# 378        NaN        NaN        NaN        NaN        NaN        NaN
# 379        NaN        NaN        NaN        NaN        NaN        NaN
# 380        NaN        NaN        NaN        NaN        NaN        NaN
# 381        NaN        NaN        NaN        NaN        NaN        NaN
# 382        NaN        NaN        NaN        NaN        NaN        NaN
# 383        NaN        NaN        NaN        NaN        NaN        NaN
# 384        NaN        NaN        NaN        NaN        NaN        NaN
# 385        NaN        NaN        NaN        NaN        NaN        NaN
#
#      27Feb2023  28Feb2023
# 334        NaN        NaN
# 335        NaN        NaN
# 336        NaN        NaN
# 337        NaN        NaN
# 338        NaN        NaN
# 339        NaN        NaN
# 340        NaN        NaN
# 341        NaN        NaN
# 342        NaN        NaN
# 343        NaN        NaN
# 344        NaN        NaN
# 345        NaN        NaN
# 346        NaN        NaN
# 347        NaN        NaN
# 348        NaN        NaN
# 349        NaN        NaN
# 350        NaN        NaN
# 351        NaN        NaN
# 352        NaN        NaN
# 353        NaN        NaN
# 354        NaN        NaN
# 355        NaN        NaN
# 356        NaN        NaN
# 357        NaN        NaN
# 358        NaN        NaN
# 359        NaN        NaN
# 360        NaN        NaN
# 361        NaN        NaN
# 362        NaN        NaN
# 363        NaN        NaN
# 364        NaN        NaN
# 365        NaN        NaN
# 366        NaN        NaN
# 367        NaN        NaN
# 368        NaN        NaN
# 369        NaN        NaN
# 370        NaN        NaN
# 371        NaN        NaN
# 372        NaN        NaN
# 373        NaN        NaN
# 374        NaN        NaN
# 375        NaN        NaN
# 376        NaN        NaN
# 377        NaN        NaN
# 378        NaN        NaN
# 379        NaN        NaN
# 380        NaN        NaN
# 381        NaN        NaN
# 382        NaN        NaN
# 383        NaN        NaN
# 384        NaN        NaN
# 385        NaN        NaN
#
# [52 rows x 1162 columns]

# %%
owid_df[owid_df['country']=='United States']
# Out:
#              country  year iso_code   population           gdp  \
# 20369  United States  1900      USA   74829905.0  6.139981e+11
# 20370  United States  1901      USA   76245912.0  6.831060e+11
# 20371  United States  1902      USA   77698268.0  6.901268e+11
# 20372  United States  1903      USA   79187838.0  7.237663e+11
# 20373  United States  1904      USA   80705948.0  7.146218e+11
# ...              ...   ...      ...          ...           ...
# 20488  United States  2019      USA  334319680.0  1.854055e+13
# 20489  United States  2020      USA  335942016.0  1.802736e+13
# 20490  United States  2021      USA  336997632.0  1.909938e+13
# 20491  United States  2022      USA  338289856.0  1.949317e+13
# 20492  United States  2023      USA  339996576.0           NaN
#
#        biofuel_cons_change_pct  biofuel_cons_change_twh  \
# 20369                      NaN                      NaN
# 20370                      NaN                      NaN
# 20371                      NaN                      NaN
# 20372                      NaN                      NaN
# 20373                      NaN                      NaN
# ...                        ...                      ...
# 20488                    2.780                   11.250
# 20489                   -9.029                  -37.549
# 20490                    9.917                   37.518
# 20491                    5.231                   21.754
# 20492                   13.215                   57.826
#
#        biofuel_cons_per_capita  biofuel_consumption  biofuel_elec_per_capita  \
# 20369                      NaN                  NaN                      NaN
# 20370                      NaN                  NaN                      NaN
# 20371                      NaN                  NaN                      NaN
# 20372                      NaN                  NaN                      NaN
# 20373                      NaN                  NaN                      NaN
# ...                        ...                  ...                      ...
# 20488                 1243.930              415.870                  172.021
# 20489                 1126.150              378.321                  162.826
# 20490                 1233.954              415.839                  160.980
# 20491                 1293.546              437.593                  153.271
# 20492                 1457.130              495.419                  139.590
#
#        ...  solar_share_elec  solar_share_energy  wind_cons_change_pct  \
# 20369  ...               NaN                 NaN                   NaN
# 20370  ...               NaN                 NaN                   NaN
# 20371  ...               NaN                 NaN                   NaN
# 20372  ...               NaN                 NaN                   NaN
# 20373  ...               NaN                 NaN                   NaN
# ...    ...               ...                 ...                   ...
# 20488  ...             2.570               1.071                 8.514
# 20489  ...             3.233               1.408                14.214
# 20490  ...             3.958               1.674                11.913
# 20491  ...             4.784               2.038                14.834
# 20492  ...             5.604               2.386                -2.087
#
#        wind_cons_change_twh  wind_consumption  wind_elec_per_capita  \
# 20369                   NaN               NaN                   NaN
# 20370                   NaN               NaN                   NaN
# 20371                   NaN               NaN                   NaN
# 20372                   NaN               NaN                   NaN
# 20373                   NaN               NaN                   NaN
# ...                     ...               ...                   ...
# 20488                59.126           787.816               885.021
# 20489               108.672           896.488              1005.947
# 20490               103.127           999.615              1122.263
# 20491               144.094          1143.709              1283.810
# 20492               -27.933          1115.776              1250.689
#
#        wind_electricity  wind_energy_per_capita  wind_share_elec  \
# 20369               NaN                     NaN              NaN
# 20370               NaN                     NaN              NaN
# 20371               NaN                     NaN              NaN
# 20372               NaN                     NaN              NaN
# 20373               NaN                     NaN              NaN
# ...                 ...                     ...              ...
# 20488            295.88                2356.476            7.115
# 20489            337.94                2668.579            8.358
# 20490            378.20                2966.237            9.105
# 20491            434.30                3380.855           10.131
# 20492            425.23                3281.726           10.008
#
#        wind_share_energy
# 20369                NaN
# 20370                NaN
# 20371                NaN
# 20372                NaN
# 20373                NaN
# ...                  ...
# 20488              2.964
# 20489              3.641
# 20490              3.851
# 20491              4.315
# 20492              4.260
#
# [124 rows x 130 columns]
