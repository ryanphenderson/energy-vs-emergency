# %%
import pandas as pd
import numpy as np

# %%
cov_compact = pd.read_csv('../data/covid-policy-dataset/data/OxCGRT_compact_national_v1.csv')

# %%
cov_compact[cov_compact['CountryName']=='United States']
# Out:
#           CountryName CountryCode  RegionName  RegionCode Jurisdiction  \
# 191800  United States         USA         NaN         NaN    NAT_TOTAL
# 191801  United States         USA         NaN         NaN    NAT_TOTAL
# 191802  United States         USA         NaN         NaN    NAT_TOTAL
# 191803  United States         USA         NaN         NaN    NAT_TOTAL
# 191804  United States         USA         NaN         NaN    NAT_TOTAL
# ...               ...         ...         ...         ...          ...
# 192891  United States         USA         NaN         NaN    NAT_TOTAL
# 192892  United States         USA         NaN         NaN    NAT_TOTAL
# 192893  United States         USA         NaN         NaN    NAT_TOTAL
# 192894  United States         USA         NaN         NaN    NAT_TOTAL
# 192895  United States         USA         NaN         NaN    NAT_TOTAL
#
#             Date  C1M_School closing  C1M_Flag  C2M_Workplace closing  \
# 191800  20200101                 0.0       NaN                    0.0
# 191801  20200102                 0.0       NaN                    0.0
# 191802  20200103                 0.0       NaN                    0.0
# 191803  20200104                 0.0       NaN                    0.0
# 191804  20200105                 0.0       NaN                    0.0
# ...          ...                 ...       ...                    ...
# 192891  20221227                 1.0       0.0                    1.0
# 192892  20221228                 1.0       0.0                    1.0
# 192893  20221229                 1.0       0.0                    1.0
# 192894  20221230                 1.0       0.0                    1.0
# 192895  20221231                 1.0       0.0                    1.0
#
#         C2M_Flag  ...  V3_Vaccine Financial Support (summary)  \
# 191800       NaN  ...                                       0
# 191801       NaN  ...                                       0
# 191802       NaN  ...                                       0
# 191803       NaN  ...                                       0
# 191804       NaN  ...                                       0
# ...          ...  ...                                     ...
# 192891       0.0  ...                                       5
# 192892       0.0  ...                                       5
# 192893       0.0  ...                                       5
# 192894       0.0  ...                                       5
# 192895       0.0  ...                                       5
#
#         V4_Mandatory Vaccination (summary)  ConfirmedCases  ConfirmedDeaths  \
# 191800                                 0.0             0.0              0.0
# 191801                                 0.0             0.0              0.0
# 191802                                 0.0             0.0              0.0
# 191803                                 0.0             0.0              0.0
# 191804                                 0.0             0.0              0.0
# ...                                    ...             ...              ...
# 192891                                 1.0     100501536.0        1090608.0
# 192892                                 1.0     100614880.0        1091598.0
# 192893                                 1.0     100718983.0        1092522.0
# 192894                                 1.0     100757380.0        1092738.0
# 192895                                 1.0     100765333.0        1092764.0
#
#         MajorityVaccinated  PopulationVaccinated  StringencyIndex_Average  \
# 191800                  NV                  0.00                     0.00
# 191801                  NV                  0.00                     0.00
# 191802                  NV                  0.00                     0.00
# 191803                  NV                  0.00                     0.00
# 191804                  NV                  0.00                     0.00
# ...                    ...                   ...                      ...
# 192891                   V                 69.13                    28.72
# 192892                   V                 69.13                    28.72
# 192893                   V                 69.14                    28.72
# 192894                   V                 69.15                    28.71
# 192895                   V                 69.15                    28.71
#
#         GovernmentResponseIndex_Average  ContainmentHealthIndex_Average  \
# 191800                             0.00                            0.00
# 191801                             0.00                            0.00
# 191802                             0.00                            0.00
# 191803                             0.00                            0.00
# 191804                             0.00                            0.00
# ...                                 ...                             ...
# 192891                            37.25                           42.57
# 192892                            37.25                           42.57
# 192893                            37.25                           42.57
# 192894                            37.25                           42.57
# 192895                            38.03                           43.46
#
#         EconomicSupportIndex
# 191800                   0.0
# 191801                   0.0
# 191802                   0.0
# 191803                   0.0
# 191804                   0.0
# ...                      ...
# 192891                   0.0
# 192892                   0.0
# 192893                   0.0
# 192894                   0.0
# 192895                   0.0
#
# [1096 rows x 56 columns]
